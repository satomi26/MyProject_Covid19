# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import datetime
plt.style.use("ggplot")
pd.set_option("display.max_columns", 200)
from ydata_profiling import ProfileReport
import sqlite3

# %%
df = pd.read_csv("covid2.csv", delimiter=",")
df.head()
# Out:
#    Unnamed: 0 iso_code continent     location        date  total_cases  \
# 0           0      AFG      Asia  Afghanistan  2020-01-03          NaN
# 1           1      AFG      Asia  Afghanistan  2020-01-04          NaN
# 2           2      AFG      Asia  Afghanistan  2020-01-05          NaN
# 3           3      AFG      Asia  Afghanistan  2020-01-06          NaN
# 4           4      AFG      Asia  Afghanistan  2020-01-07          NaN
#
#    new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0        0.0           NaN         0.0                      NaN
# 1        0.0           NaN         0.0                      NaN
# 2        0.0           NaN         0.0                      NaN
# 3        0.0           NaN         0.0                      NaN
# 4        0.0           NaN         0.0                      NaN
#
#    new_cases_per_million  total_deaths_per_million  new_deaths_per_million  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297093 entries, 0 to 297092
# Data columns (total 38 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           297093 non-null  int64
#  1   iso_code                             297093 non-null  object
#  2   continent                            282979 non-null  object
#  3   location                             297093 non-null  object
#  4   date                                 297093 non-null  object
#  5   total_cases                          261401 non-null  float64
#  6   new_cases                            288675 non-null  float64
#  7   total_deaths                         240987 non-null  float64
#  8   new_deaths                           288741 non-null  float64
#  9   total_cases_per_million              261401 non-null  float64
# ...

# %%
world = df[df.location == "World"]
world.head()
# Out:
#         Unnamed: 0  iso_code continent location       date  total_cases  \
# 292394      292394  OWID_WRL       NaN    World 2020-01-03          NaN
# 292395      292395  OWID_WRL       NaN    World 2020-01-04          3.0
# 292396      292396  OWID_WRL       NaN    World 2020-01-05          3.0
# 292397      292397  OWID_WRL       NaN    World 2020-01-06          6.0
# 292398      292398  OWID_WRL       NaN    World 2020-01-07          6.0
#
#         new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 292394        0.0           NaN         0.0                      NaN
# 292395        3.0           NaN         0.0                    0.000
# 292396        0.0           NaN         0.0                    0.000
# 292397        3.0           NaN         0.0                    0.001
# 292398        0.0           NaN         0.0                    0.001
#
#         new_cases_per_million  total_deaths_per_million  \
# 292394                    0.0                       NaN
# ...

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'England',
# ...

# %%
df = df[df.location != "Africa"]
df = df[df.location != "Asia"]
df = df[df.location != "North America"]
df = df[df.location != "South America"]
df = df[df.location != "Europe"]
df = df[df.location != "European Union"]
df = df[df.location != "Oceania"]
df = df[df.location != "High income "]
df = df[df.location != "Upper middle income"]
df = df[df.location != "Lower middle income"]

# %%
df = df[df.location != "High income"]
df = df[df.location != "Low income"]
df = df[df.location != "World"]

# %%
df.drop(["icu_patients", "hosp_patients", "reproduction_rate", "total_vaccinations", "total_boosters", "new_vaccinations"], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 282979 entries, 0 to 297092
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           282979 non-null  int64
#  1   iso_code                             282979 non-null  object
#  2   continent                            282979 non-null  object
#  3   location                             282979 non-null  object
#  4   date                                 282979 non-null  datetime64[ns]
#  5   total_cases                          247527 non-null  float64
#  6   new_cases                            274587 non-null  float64
#  7   total_deaths                         227395 non-null  float64
#  8   new_deaths                           274653 non-null  float64
#  9   total_cases_per_million              247527 non-null  float64
# ...

# %%
print(df.location.unique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia' 'Bonaire Sint Eustatius and Saba' 'Bosnia and Herzegovina'
#  'Botswana' 'Brazil' 'British Virgin Islands' 'Brunei' 'Bulgaria'
#  'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon' 'Canada' 'Cape Verde'
#  'Cayman Islands' 'Central African Republic' 'Chad' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo' 'Cook Islands' 'Costa Rica' "Cote d'Ivoire"
#  'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia'
#  'Democratic Republic of Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'England'
#  'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini' 'Ethiopia'
#  'Faeroe Islands' 'Falkland Islands' 'Fiji' 'Finland' 'France'
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0   total_cases     new_cases  total_deaths     new_deaths  \
# count  286507.000000  2.509950e+05  2.781090e+05  2.307950e+05  278175.000000
# mean   148893.887992  3.365005e+06  6.984274e+03  4.696692e+04      59.865843
# std     85435.245112  3.016315e+07  8.537930e+04  3.553628e+05     522.821541
# min         0.000000  1.000000e+00  0.000000e+00  1.000000e+00       0.000000
# 25%     73977.500000  5.602000e+03  0.000000e+00  1.080000e+02       0.000000
# 50%    147958.000000  4.846700e+04  1.600000e+01  9.470000e+02       0.000000
# 75%    223112.500000  4.733045e+05  4.360000e+02  8.300000e+03       5.000000
# max    297092.000000  7.610711e+08  7.946912e+06  6.879664e+06   20005.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             250995.00000          278109.000000
# mean               82643.75682             169.043866
# std               133332.98301            1164.431903
# ...

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286507 entries, 0 to 297092
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           286507 non-null  int64
#  1   iso_code                             286507 non-null  object
#  2   continent                            282979 non-null  object
#  3   location                             286507 non-null  object
#  4   date                                 286507 non-null  datetime64[ns]
#  5   total_cases                          250995 non-null  float64
#  6   new_cases                            278109 non-null  float64
#  7   total_deaths                         230795 non-null  float64
#  8   new_deaths                           278175 non-null  float64
#  9   total_cases_per_million              250995 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'iso_code', 'continent', 'location', 'date',
#        'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'total_cases_per_million', 'new_cases_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million', 'positive_rate',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative', 'excess_mortality'],
#       dtype='object')

# %%
df_general = df[['iso_code', 'continent', 'location', 'date',
       'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
       'total_cases_per_million', 'new_cases_per_million',
       'total_deaths_per_million', 'new_deaths_per_million', 'positive_rate',
       'people_vaccinated', 'people_fully_vaccinated',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'median_age', 'aged_65_older', 'aged_70_older',
       'gdp_per_capita', 'female_smokers', 'male_smokers', 
       'life_expectancy', "population"]]

# %%
df_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 282979 entries, 0 to 297092
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   iso_code                             282979 non-null  object
#  1   continent                            282979 non-null  object
#  2   location                             282979 non-null  object
#  3   date                                 282979 non-null  datetime64[ns]
#  4   total_cases                          247527 non-null  float64
#  5   new_cases                            274587 non-null  float64
#  6   total_deaths                         227395 non-null  float64
#  7   new_deaths                           274653 non-null  float64
#  8   total_cases_per_million              247527 non-null  float64
#  9   new_cases_per_million                274587 non-null  float64
# ...

# %%
df_general.to_csv("covid_01.csv")

# %%
df.to_csv("covid_cleaned.csv")

# %%
world = df[df.location == "World"]
world.head()
# Out:
#         Unnamed: 0  iso_code continent location       date  total_cases  \
# 292394      292394  OWID_WRL       NaN    World 2020-01-03          NaN
# 292395      292395  OWID_WRL       NaN    World 2020-01-04          3.0
# 292396      292396  OWID_WRL       NaN    World 2020-01-05          3.0
# 292397      292397  OWID_WRL       NaN    World 2020-01-06          6.0
# 292398      292398  OWID_WRL       NaN    World 2020-01-07          6.0
#
#         new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 292394        0.0           NaN         0.0                      NaN
# 292395        3.0           NaN         0.0                    0.000
# 292396        0.0           NaN         0.0                    0.000
# 292397        3.0           NaN         0.0                    0.001
# 292398        0.0           NaN         0.0                    0.001
#
#         new_cases_per_million  total_deaths_per_million  \
# 292394                    0.0                       NaN
# ...

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1177 entries, 292394 to 293570
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           1177 non-null   int64
#  1   iso_code                             1177 non-null   object
#  2   continent                            0 non-null      object
#  3   location                             1177 non-null   object
#  4   date                                 1177 non-null   datetime64[ns]
#  5   total_cases                          1173 non-null   float64
#  6   new_cases                            1174 non-null   float64
#  7   total_deaths                         1165 non-null   float64
#  8   new_deaths                           1174 non-null   float64
#  9   total_cases_per_million              1173 non-null   float64
# ...

# %%
world.drop(["icu_patients", "hosp_patients", "reproduction_rate", "total_vaccinations", "total_boosters", "new_vaccinations"], axis = 1, inplace = True)
# Out:
# C:\Users\satom\AppData\Local\Temp\ipykernel_12700\1038379574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   world.drop(["icu_patients", "hosp_patients", "reproduction_rate", "total_vaccinations", "total_boosters", "new_vaccinations"], axis = 1, inplace = True)

# %%
world.head()
# Out:
#         Unnamed: 0  iso_code continent location       date  total_cases  \
# 292394      292394  OWID_WRL       NaN    World 2020-01-03          NaN
# 292395      292395  OWID_WRL       NaN    World 2020-01-04          3.0
# 292396      292396  OWID_WRL       NaN    World 2020-01-05          3.0
# 292397      292397  OWID_WRL       NaN    World 2020-01-06          6.0
# 292398      292398  OWID_WRL       NaN    World 2020-01-07          6.0
#
#         new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 292394        0.0           NaN         0.0                      NaN
# 292395        3.0           NaN         0.0                    0.000
# 292396        0.0           NaN         0.0                    0.000
# 292397        3.0           NaN         0.0                    0.001
# 292398        0.0           NaN         0.0                    0.001
#
#         new_cases_per_million  total_deaths_per_million  \
# 292394                    0.0                       NaN
# ...

# %%
world.to_csv("world.csv")

# %%
germany = df[df.location == "Germany"]
germany.head()

# %%
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1178 entries, 96234 to 97411
# Data columns (total 38 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           1178 non-null   int64
#  1   iso_code                             1178 non-null   object
#  2   continent                            1178 non-null   object
#  3   location                             1178 non-null   object
#  4   date                                 1178 non-null   datetime64[ns]
#  5   total_cases                          1173 non-null   float64
#  6   new_cases                            1174 non-null   float64
#  7   total_deaths                         1125 non-null   float64
#  8   new_deaths                           1174 non-null   float64
#  9   total_cases_per_million              1173 non-null   float64
#  10  new_cases_per_million                1174 non-null   float64
# ...

# %%
germany.to_csv("germany.csv")

# %%
japan = df[df.location == "Japan"]
japan.head()
# Out:
#         Unnamed: 0 iso_code continent location       date  total_cases  \
# 129097      129097      JPN      Asia    Japan 2020-01-03          NaN
# 129098      129098      JPN      Asia    Japan 2020-01-04          NaN
# 129099      129099      JPN      Asia    Japan 2020-01-05          NaN
# 129100      129100      JPN      Asia    Japan 2020-01-06          NaN
# 129101      129101      JPN      Asia    Japan 2020-01-07          NaN
#
#         new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 129097        0.0           NaN         0.0                      NaN
# 129098        0.0           NaN         0.0                      NaN
# 129099        0.0           NaN         0.0                      NaN
# 129100        0.0           NaN         0.0                      NaN
# 129101        0.0           NaN         0.0                      NaN
#
#         new_cases_per_million  total_deaths_per_million  \
# 129097                    0.0                       NaN
# ...
